# %%
import numpy as np
import xarray as xr 

import matplotlib.pylab as plt
from matplotlib.colors import BoundaryNorm
import glidertools as gt

from cmocean import cm as cmo

import gsw

# %%
data_dir = '/Users/dhruvbalwada/OneDrive/sogos_data'
data_659 = data_dir+'/data/glider_data_march/SG659_SOGOS.nc'
data_660 = data_dir+'/data/glider_data_march/SG660_SOGOS.nc'

# %%
ds_659 = xr.load_dataset(data_659)
ds_660 = xr.load_dataset(data_660)

# %%
ds_659
# Out:
# <xarray.Dataset>
# Dimensions:                    (depth: 98, length: 2830, opt_depth: 75)
# Dimensions without coordinates: depth, length, opt_depth
# Data variables:
#     Temperature_degC           (length, depth) float64 3.025 3.058 ... 2.202
#     Salinity_PSU               (length, depth) float64 33.87 33.87 ... 34.82
#     DissolvedOxygen_molperkg   (length, depth) float64 320.5 320.5 ... 136.8
#     Pressure_dbar              (depth) float64 15.0 25.0 35.0 ... 975.0 985.0
#     Time_JulDay                (length) float64 nan 120.8 120.8 ... 206.0 206.1
#     Longitude_degE             (length) float64 nan 30.85 30.85 ... 38.99 38.99
#     Latitude_degN              (length) float64 nan -51.26 ... -51.7 -51.7
#     Backscatter470nm_permeter  (length, opt_depth) float64 0.0005998 ... nan
#     Backscatter700nm_permeter  (length, opt_depth) float64 0.0006999 ... nan
#     Fluorescence_mgperm3       (length, opt_depth) float64 0.2275 0.2276 ... nan
# ...

# %%
ds_659.Time_JulDay.diff('length').plot()
